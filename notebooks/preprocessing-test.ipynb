# %%
import sys
sys.path.append("../src")

from preprocessing import preprocess_text

# English
text_en = open("../data/raw/english.txt").read()
print("English:", preprocess_text(text_en, lang="en"))

# French
text_fr = open("../data/raw/french.txt").read()
print("French:", preprocess_text(text_fr, lang="fr"))
# Out:
# English: computer science evergrowe field machine learning datum analysis core
# French: science informatique évoluer rapidement lapprentissage automatique analyse donnée essentiel
